# %%
# !pip install --upgrade seqeval evaluate transformers==4.28.1 torch datasets huggingface_hub ipywidgets

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="4"
EXP_NAME = 'exp-991-mbert'
from transformers import AutoModel, AutoTokenizer, AutoModelForTokenClassification, TrainingArguments, Trainer, DataCollatorForTokenClassification
import torch
import json
import numpy as np
import pandas as pd
from datasets import Dataset, load_metric
from sklearn.metrics import f1_score
from seqeval.metrics import classification_report
from tabulate import tabulate

# %%
class_list = ["Tanggal Putusan", "Nama Hakim Ketua", "Nama Hakim Anggota", "Nama Panitera",
              "Putusan Hukuman", "Jenis Amar", "Melanggar UU (Pertimbangan Hukum)", "Melanggar UU (Dakwaan)",
              "Jenis Dakwaan", "Tanggal Kejadian", "Nama Saksi", "Tuntutan Hukuman", "Melanggar UU (Tuntutan)",
              "Jenis Perkara", "Nama Terdakwa", "Nama Pengadilan", "Tingkat Kasus", "Nomor Putusan", "Nama Jaksa",
              "Nama Pengacara"]
label_list = ['O']
label_list.extend([_ for __ in [[f'B-{cl}', f'I-{cl}'] for cl in class_list] for _ in __])
print(label_list)
# Out:
# ['O', 'B-Tanggal Putusan', 'I-Tanggal Putusan', 'B-Nama Hakim Ketua', 'I-Nama Hakim Ketua', 'B-Nama Hakim Anggota', 'I-Nama Hakim Anggota', 'B-Nama Panitera', 'I-Nama Panitera', 'B-Putusan Hukuman', 'I-Putusan Hukuman', 'B-Jenis Amar', 'I-Jenis Amar', 'B-Melanggar UU (Pertimbangan Hukum)', 'I-Melanggar UU (Pertimbangan Hukum)', 'B-Melanggar UU (Dakwaan)', 'I-Melanggar UU (Dakwaan)', 'B-Jenis Dakwaan', 'I-Jenis Dakwaan', 'B-Tanggal Kejadian', 'I-Tanggal Kejadian', 'B-Nama Saksi', 'I-Nama Saksi', 'B-Tuntutan Hukuman', 'I-Tuntutan Hukuman', 'B-Melanggar UU (Tuntutan)', 'I-Melanggar UU (Tuntutan)', 'B-Jenis Perkara', 'I-Jenis Perkara', 'B-Nama Terdakwa', 'I-Nama Terdakwa', 'B-Nama Pengadilan', 'I-Nama Pengadilan', 'B-Tingkat Kasus', 'I-Tingkat Kasus', 'B-Nomor Putusan', 'I-Nomor Putusan', 'B-Nama Jaksa', 'I-Nama Jaksa', 'B-Nama Pengacara', 'I-Nama Pengacara']

# %%
id2label = {}
label2id = {}
for idx, x in enumerate(label_list):
    label2id[x] = idx
    id2label[idx] = x

# %%
def process_input(filename):
  tokens = []
  tags = []
  with open(filename, 'r', encoding="utf8") as f:
    for line in f:
      data = json.loads(line)
      tokens.append(data['text'])
      tags.append(data['text-tags'])
  
  return pd.DataFrame({'tokens': tokens, "tags": tags})

# %%
dataset_train = process_input("data/out.train.jsonl")
dataset_test = process_input("data/out.test.jsonl")
ds_train = Dataset.from_pandas(dataset_train)
ds_test = Dataset.from_pandas(dataset_test)

# %%
tokenizer = AutoTokenizer.from_pretrained(EXP_NAME)

# %%
def split_tokens(row):
    label_all_data = True
    tokens = tokenizer(
        list(row["tokens"]),
        is_split_into_words=True,
        max_length=512,
        truncation=True,
        return_overflowing_tokens=True,
        return_length=True,
        padding=True
    )
    token = []
    labels = []
    word_ids = []
    
    for i in range(len(tokens.length)):
        m_label = []
        prev_word_idx = None
        token.append(tokens.tokens(i))
        for word_idx in tokens.word_ids(i):
            word_ids.append(word_idx)
            if word_idx is None:
                m_label.append(-100)
            elif word_idx != prev_word_idx:
                m_label.append(label2id[row["tags"][word_idx]])
            else:
                m_label.append(label2id[row["tags"][word_idx]] if label_all_data else -99)
            prev_word_idx = word_idx
        labels.append(m_label)
    tokens['token'] = token
    tokens['labels'] = labels
    tokens['word_ids'] = word_ids
    return tokens

# %%
test_tokenized_datasets = ds_test.map(split_tokens)
# Out:
# Map:   0%|          | 0/269 [00:00<?, ? examples/s]

# %%
dropped_col = ['tokens', 'tags', 'length', 'overflow_to_sample_mapping']

# %%
def flatten_pandas_ds(ds): 
    cols = list(ds)
    out = {}
    
    for i in cols:
        d1 = []
        for d1d in ds[i].values.tolist():
            for d2d in d1d.tolist():
                d1.append(d2d)
        out[i] = d1
    return pd.DataFrame(out)

# %%
pd_test_tokenized_datasets = test_tokenized_datasets.to_pandas()
pd_test_tokenized_datasets = pd_test_tokenized_datasets.drop(dropped_col, axis=1)
word_pd = pd_test_tokenized_datasets.pop('word_ids')
pd_test_tokenized_datasets_flat = flatten_pandas_ds(pd_test_tokenized_datasets)

# %%
test_flat_ds = Dataset.from_pandas(pd_test_tokenized_datasets_flat)

# %%
import evaluate

seqeval = evaluate.load('seqeval')

# %%
data_collator = DataCollatorForTokenClassification(tokenizer, return_tensors="pt")

# %%
def flatten(l):
    return [item for sublist in l for item in sublist]

# %%
EXP_NAME = 'exp-992-mbert'

# %%
model = AutoModelForTokenClassification.from_pretrained(EXP_NAME, num_labels=41, id2label=id2label, label2id=label2id)

# %%
args = TrainingArguments(
    output_dir=EXP_NAME,
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    gradient_accumulation_steps=1,
    num_train_epochs=16,
)

args.set_optimizer(name="adamw_torch", beta1=0.9)

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=test_flat_ds,
    eval_dataset=test_flat_ds,
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# %% [markdown]
# ## Evaluation

# %%
eval_ds = test_flat_ds.remove_columns('labels')

# %%
pred = trainer.predict(eval_ds)

# %%
reference = [list(x) for x in test_flat_ds['labels']]

# %%
flat_word_id = []
for i in word_pd:
    for j in i:
        flat_word_id.append(j)

# %%
import math

pickup = []
prev_word = -100
for word_id in flat_word_id:
    if word_id <= -1 or math.isnan(word_id) :
        pickup.append(False)
    elif word_id == prev_word:
        pickup.append(False)
    else:
        pickup.append(True)
        prev_word = word_id

# %%
dt_refs, dt_preds = zip(*[(id2label[x], id2label[y]) for x,y,p in zip(flatten(reference), flatten(np.argmax(pred.predictions, -1)), pickup) if p and x>-1 and y > -1])

# %%
with open(f'real-analytics/{EXP_NAME}-analytics.txt', 'w') as f:
    rep = classification_report([list(dt_refs)], [list(dt_preds)], digits=4)
    print(rep)
    f.write(rep)
# Out:
#                                    precision    recall  f1-score   support
#
#                        Jenis Amar     0.9065    0.9618    0.9333       262
#                     Jenis Dakwaan     0.8875    0.9301    0.9083       229
#                     Jenis Perkara     0.6109    0.7451    0.6714       255
#            Melanggar UU (Dakwaan)     0.7243    0.7592    0.7414       353
# Melanggar UU (Pertimbangan Hukum)     0.7456    0.7143    0.7296       357
#           Melanggar UU (Tuntutan)     0.8045    0.8492    0.8263       252
#                Nama Hakim Anggota     0.8721    0.9416    0.9055       514
#                  Nama Hakim Ketua     0.8622    0.9208    0.8905       265
#                        Nama Jaksa     0.8790    0.9500    0.9131       260
#                     Nama Panitera     0.8754    0.9389    0.9061       262
#                    Nama Pengacara     0.8049    0.8800    0.8408        75
#                   Nama Pengadilan     0.9487    0.9885    0.9682       262
#                        Nama Saksi     0.8324    0.8517    0.8420      1079
#                     Nama Terdakwa     0.8024    0.8318    0.8168       327
#                     Nomor Putusan     0.7300    0.8172    0.7711       268
#                   Putusan Hukuman     0.6765    0.7143    0.6949       322
#                  Tanggal Kejadian     0.6686    0.6327    0.6501       373
#                   Tanggal Putusan     0.9185    0.9502    0.9341       261
#                     Tingkat Kasus     0.9442    0.9695    0.9567       262
#                  Tuntutan Hukuman     0.7983    0.8754    0.8351       321
#
#                         micro avg     0.8125    0.8533    0.8324      6559
#                         macro avg     0.8146    0.8611    0.8368      6559
#                      weighted avg     0.8128    0.8533    0.8322      6559

# %%
y_pred_df_mix = pd.Series(list(dt_preds), name="Predicted")
y_true_df_mix = pd.Series(list(dt_refs), name="Reference")
df_confusion_mix = pd.crosstab(y_true_df_mix, y_pred_df_mix)

# %%
df_confusion_mix
# Out:
# Predicted                            B-Jenis Amar  B-Jenis Dakwaan  \
# Reference
# B-Jenis Amar                                  259                0
# B-Jenis Dakwaan                                 0              219
# B-Jenis Perkara                                 0                0
# B-Melanggar UU (Dakwaan)                        0                1
# B-Melanggar UU (Pertimbangan Hukum)             0                0
# B-Melanggar UU (Tuntutan)                       0                0
# B-Nama Hakim Anggota                            0                0
# B-Nama Hakim Ketua                              0                0
# B-Nama Jaksa                                    0                0
# B-Nama Panitera                                 0                0
# B-Nama Pengacara                                0                0
# B-Nama Pengadilan                               0                0
# B-Nama Saksi                                    0                0
# B-Nama Terdakwa                                 0                0
# B-Nomor Putusan                                 0                0
# B-Putusan Hukuman                               0                0
# B-Tanggal Kejadian                              0                1
# B-Tanggal Putusan                               0                0
# B-Tingkat Kasus                                 0                0
# B-Tuntutan Hukuman                              0                0
# I-Jenis Amar                                    0                0
# I-Jenis Dakwaan                                 0                2
# I-Jenis Perkara                                 0                0
# I-Melanggar UU (Dakwaan)                        0                0
# I-Melanggar UU (Pertimbangan Hukum)             0                0
# I-Melanggar UU (Tuntutan)                       0                0
# I-Nama Hakim Anggota                            0                0
# I-Nama Hakim Ketua                              0                0
# I-Nama Jaksa                                    0                0
# I-Nama Panitera                                 0                0
# I-Nama Pengacara                                0                0
# I-Nama Pengadilan                               0                0
# I-Nama Saksi                                    0                0
# I-Nama Terdakwa                                 0                0
# I-Nomor Putusan                                 0                0
# I-Putusan Hukuman                               0                0
# I-Tanggal Kejadian                              0                0
# I-Tanggal Putusan                               0                0
# I-Tingkat Kasus                                 0                0
# I-Tuntutan Hukuman                              0                0
# O                                              13               17
#
# Predicted                            B-Jenis Perkara  \
# Reference
# B-Jenis Amar                                       0
# B-Jenis Dakwaan                                    0
# B-Jenis Perkara                                  223
# B-Melanggar UU (Dakwaan)                           0
# B-Melanggar UU (Pertimbangan Hukum)                0
# B-Melanggar UU (Tuntutan)                          0
# B-Nama Hakim Anggota                               0
# B-Nama Hakim Ketua                                 0
# B-Nama Jaksa                                       0
# B-Nama Panitera                                    0
# B-Nama Pengacara                                   0
# B-Nama Pengadilan                                  0
# B-Nama Saksi                                       0
# B-Nama Terdakwa                                    0
# B-Nomor Putusan                                    0
# B-Putusan Hukuman                                  0
# B-Tanggal Kejadian                                 0
# B-Tanggal Putusan                                  0
# B-Tingkat Kasus                                    0
# B-Tuntutan Hukuman                                 0
# I-Jenis Amar                                       0
# I-Jenis Dakwaan                                    0
# I-Jenis Perkara                                    4
# I-Melanggar UU (Dakwaan)                           0
# I-Melanggar UU (Pertimbangan Hukum)                0
# I-Melanggar UU (Tuntutan)                          0
# I-Nama Hakim Anggota                               0
# I-Nama Hakim Ketua                                 0
# I-Nama Jaksa                                       0
# I-Nama Panitera                                    0
# I-Nama Pengacara                                   0
# I-Nama Pengadilan                                  0
# I-Nama Saksi                                       0
# I-Nama Terdakwa                                    0
# I-Nomor Putusan                                    0
# I-Putusan Hukuman                                  0
# I-Tanggal Kejadian                                 0
# I-Tanggal Putusan                                  0
# I-Tingkat Kasus                                    0
# I-Tuntutan Hukuman                                 0
# O                                                 64
#
# Predicted                            B-Melanggar UU (Dakwaan)  \
# Reference
# B-Jenis Amar                                                0
# B-Jenis Dakwaan                                             0
# B-Jenis Perkara                                             0
# B-Melanggar UU (Dakwaan)                                  311
# B-Melanggar UU (Pertimbangan Hukum)                         0
# B-Melanggar UU (Tuntutan)                                   1
# B-Nama Hakim Anggota                                        0
# B-Nama Hakim Ketua                                          0
# B-Nama Jaksa                                                0
# B-Nama Panitera                                             0
# B-Nama Pengacara                                            0
# B-Nama Pengadilan                                           0
# B-Nama Saksi                                                0
# B-Nama Terdakwa                                             0
# B-Nomor Putusan                                             1
# B-Putusan Hukuman                                           0
# B-Tanggal Kejadian                                          0
# B-Tanggal Putusan                                           0
# B-Tingkat Kasus                                             0
# B-Tuntutan Hukuman                                          0
# I-Jenis Amar                                                0
# I-Jenis Dakwaan                                             0
# I-Jenis Perkara                                             0
# I-Melanggar UU (Dakwaan)                                   11
# I-Melanggar UU (Pertimbangan Hukum)                         0
# I-Melanggar UU (Tuntutan)                                   0
# I-Nama Hakim Anggota                                        0
# I-Nama Hakim Ketua                                          0
# I-Nama Jaksa                                                0
# I-Nama Panitera                                             0
# I-Nama Pengacara                                            0
# I-Nama Pengadilan                                           0
# I-Nama Saksi                                                0
# I-Nama Terdakwa                                             0
# I-Nomor Putusan                                             0
# I-Putusan Hukuman                                           0
# I-Tanggal Kejadian                                          0
# I-Tanggal Putusan                                           0
# I-Tingkat Kasus                                             0
# I-Tuntutan Hukuman                                          0
# O                                                          26
#
# Predicted                            B-Melanggar UU (Pertimbangan Hukum)  \
# Reference
# Predicted                            B-Nama Hakim Anggota  B-Nama Hakim Ketua  \
# Reference
# B-Jenis Amar                                            0                   0
# B-Jenis Dakwaan                                         0                   0
# B-Jenis Perkara                                         0                   0
# B-Melanggar UU (Dakwaan)                                0                   0
# B-Melanggar UU (Pertimbangan Hukum)                     0                   0
# B-Melanggar UU (Tuntutan)                               0                   0
# B-Nama Hakim Anggota                                  504                   0
# B-Nama Hakim Ketua                                      3                 258
# B-Nama Jaksa                                            0                   0
# B-Nama Panitera                                         1                   0
# B-Nama Pengacara                                        0                   0
# B-Nama Pengadilan                                       0                   0
# B-Nama Saksi                                            0                   0
# B-Nama Terdakwa                                         0                   0
# B-Nomor Putusan                                         0                   0
# B-Putusan Hukuman                                       0                   0
# B-Tanggal Kejadian                                      0                   0
# B-Tanggal Putusan                                       0                   0
# B-Tingkat Kasus                                         0                   0
# B-Tuntutan Hukuman                                      0                   0
# I-Jenis Amar                                            0                   0
# I-Jenis Dakwaan                                         0                   0
# I-Jenis Perkara                                         0                   0
# I-Melanggar UU (Dakwaan)                                0                   0
# I-Melanggar UU (Pertimbangan Hukum)                     0                   0
# I-Melanggar UU (Tuntutan)                               0                   0
# I-Nama Hakim Anggota                                   14                   0
# I-Nama Hakim Ketua                                      0                  12
# I-Nama Jaksa                                            0                   0
# I-Nama Panitera                                         0                   0
# I-Nama Pengacara                                        0                   0
# I-Nama Pengadilan                                       0                   0
# I-Nama Saksi                                            0                   0
# I-Nama Terdakwa                                         0                   0
# I-Nomor Putusan                                         0                   0
# I-Putusan Hukuman                                       0                   0
# I-Tanggal Kejadian                                      0                   0
# I-Tanggal Putusan                                       0                   0
# I-Tingkat Kasus                                         0                   0
# I-Tuntutan Hukuman                                      0                   0
# O                                                      31                  10
#
# Predicted                            B-Nama Jaksa  B-Nama Panitera  ...  \
# Reference                                                           ...
# B-Jenis Amar                                    0                0  ...
# B-Jenis Dakwaan                                 0                0  ...
# B-Jenis Perkara                                 0                0  ...
# B-Melanggar UU (Dakwaan)                        0                0  ...
# B-Melanggar UU (Pertimbangan Hukum)             0                0  ...
# B-Melanggar UU (Tuntutan)                       0                0  ...
# B-Nama Hakim Anggota                            0                1  ...
# B-Nama Hakim Ketua                              0                0  ...
# B-Nama Jaksa                                  258                1  ...
# B-Nama Panitera                                 1              255  ...
# B-Nama Pengacara                                0                0  ...
# B-Nama Pengadilan                               0                0  ...
# B-Nama Saksi                                    0                0  ...
# B-Nama Terdakwa                                 0                0  ...
# B-Nomor Putusan                                 0                0  ...
# B-Putusan Hukuman                               0                0  ...
# B-Tanggal Kejadian                              0                0  ...
# B-Tanggal Putusan                               0                0  ...
# B-Tingkat Kasus                                 0                0  ...
# B-Tuntutan Hukuman                              0                0  ...
# I-Jenis Amar                                    0                0  ...
# I-Jenis Dakwaan                                 0                0  ...
# I-Jenis Perkara                                 0                0  ...
# I-Melanggar UU (Dakwaan)                        0                0  ...
# I-Melanggar UU (Pertimbangan Hukum)             0                0  ...
# I-Melanggar UU (Tuntutan)                       0                0  ...
# I-Nama Hakim Anggota                            0                0  ...
# I-Nama Hakim Ketua                              0                0  ...
# I-Nama Jaksa                                    9                0  ...
# I-Nama Panitera                                 0                7  ...
# I-Nama Pengacara                                0                0  ...
# I-Nama Pengadilan                               0                0  ...
# I-Nama Saksi                                    0                0  ...
# I-Nama Terdakwa                                 0                0  ...
# I-Nomor Putusan                                 0                0  ...
# I-Putusan Hukuman                               0                0  ...
# I-Tanggal Kejadian                              0                0  ...
# I-Tanggal Putusan                               0                0  ...
# I-Tingkat Kasus                                 0                0  ...
# I-Tuntutan Hukuman                              0                0  ...
# O                                              13               15  ...
#
# Predicted                            I-Nama Pengadilan  I-Nama Saksi  \
# Reference
# B-Jenis Amar                                         0             0
# B-Jenis Dakwaan                                      0             0
# B-Jenis Perkara                                      0             0
# B-Melanggar UU (Dakwaan)                             0             0
# B-Melanggar UU (Pertimbangan Hukum)                  0             0
# B-Melanggar UU (Tuntutan)                            0             0
# B-Nama Hakim Anggota                                 0             0
# B-Nama Hakim Ketua                                   0             0
# B-Nama Jaksa                                         0             0
# B-Nama Panitera                                      0             0
# B-Nama Pengacara                                     0             0
# B-Nama Pengadilan                                    1             0
# B-Nama Saksi                                         0             7
# B-Nama Terdakwa                                      0             0
# B-Nomor Putusan                                      0             0
# B-Putusan Hukuman                                    0             0
# B-Tanggal Kejadian                                   0             0
# B-Tanggal Putusan                                    0             0
# B-Tingkat Kasus                                      0             0
# B-Tuntutan Hukuman                                   0             0
# I-Jenis Amar                                         0             0
# I-Jenis Dakwaan                                      0             0
# I-Jenis Perkara                                      0             0
# I-Melanggar UU (Dakwaan)                             0             0
# I-Melanggar UU (Pertimbangan Hukum)                  0             0
# I-Melanggar UU (Tuntutan)                            0             0
# I-Nama Hakim Anggota                                 0             0
# I-Nama Hakim Ketua                                   0             0
# I-Nama Jaksa                                         0             0
# I-Nama Panitera                                      0             0
# I-Nama Pengacara                                     0             0
# I-Nama Pengadilan                                  586             0
# I-Nama Saksi                                         0          2266
# I-Nama Terdakwa                                      0             0
# I-Nomor Putusan                                      8             0
# I-Putusan Hukuman                                    0             0
# I-Tanggal Kejadian                                   0             0
# I-Tanggal Putusan                                    0             0
# I-Tingkat Kasus                                      0             0
# I-Tuntutan Hukuman                                   0            12
# O                                                   20           223
#
# Predicted                            I-Nama Terdakwa  I-Nomor Putusan  \
# Reference
# B-Jenis Amar                                       0                0
# B-Jenis Dakwaan                                    0                0
# B-Jenis Perkara                                    0                0
# B-Melanggar UU (Dakwaan)                           0                0
# B-Melanggar UU (Pertimbangan Hukum)                0                0
# B-Melanggar UU (Tuntutan)                          0                0
# B-Nama Hakim Anggota                               0                0
# B-Nama Hakim Ketua                                 0                0
# B-Nama Jaksa                                       0                0
# B-Nama Panitera                                    0                0
# B-Nama Pengacara                                   0                0
# B-Nama Pengadilan                                  0                0
# B-Nama Saksi                                       0                0
# B-Nama Terdakwa                                    0                0
# B-Nomor Putusan                                    0                1
# B-Putusan Hukuman                                  0                0
# B-Tanggal Kejadian                                 0                0
# B-Tanggal Putusan                                  0                0
# B-Tingkat Kasus                                    0                0
# B-Nama Jaksa                                         0                0
# B-Nama Panitera                                      0                0
# B-Nama Pengacara                                     0                0
# B-Nama Pengadilan                                    0                0
# B-Nama Saksi                                         0                0
# B-Nama Terdakwa                                      0                0
# B-Nomor Putusan                                      0                0
# B-Putusan Hukuman                                    0                0
# B-Tanggal Kejadian                                   0                0
# B-Tanggal Putusan                                    0                0
# B-Tingkat Kasus                                      0                1
# B-Tuntutan Hukuman                                   0                0
# I-Jenis Amar                                         0                0
# I-Jenis Dakwaan                                      0                0
# I-Jenis Perkara                                      0                0
# I-Melanggar UU (Dakwaan)                             0                0
# I-Melanggar UU (Pertimbangan Hukum)                  0                0
# I-Melanggar UU (Tuntutan)                            0                0
# I-Nama Hakim Anggota                                 0                0
# I-Nama Hakim Ketua                                   0                0
# I-Nama Jaksa                                         0                0
# I-Nama Panitera                                      0                0
# I-Nama Pengacara                                     0                0
# I-Nama Pengadilan                                    0                0
# I-Nama Saksi                                         0                0
# I-Nama Terdakwa                                      0                0
# I-Nomor Putusan                                      0                0
# I-Putusan Hukuman                                    0                0
# I-Tanggal Kejadian                                   0                0
# I-Tanggal Putusan                                  514                0
# I-Tingkat Kasus                                      0              286
# I-Tuntutan Hukuman                                   0                0
# O                                                   28               11
#
# Predicted                            I-Tuntutan Hukuman        O
# Reference
# B-Jenis Amar                                          0        3
# B-Jenis Dakwaan                                       0       10
# B-Jenis Perkara                                       0       26
# B-Melanggar UU (Dakwaan)                              0       40
# B-Melanggar UU (Pertimbangan Hukum)                   0       76
# B-Melanggar UU (Tuntutan)                             0        4
# B-Nama Hakim Anggota                                  0        2
# B-Nama Hakim Ketua                                    0        4
# B-Nama Jaksa                                          0        0
# B-Nama Panitera                                       0        1
# B-Nama Pengacara                                      0        3
# B-Nama Pengadilan                                     0        1
# B-Nama Saksi                                          0       68
# B-Nama Terdakwa                                       0       11
# B-Nomor Putusan                                       0       20
# B-Putusan Hukuman                                     0       11
# B-Tanggal Kejadian                                    0      132
# B-Tanggal Putusan                                     0        8
# B-Tingkat Kasus                                       0        5
# B-Tuntutan Hukuman                                    4       14
# I-Jenis Amar                                          0       15
# I-Jenis Dakwaan                                       0       24
# I-Jenis Perkara                                       0       26
# I-Melanggar UU (Dakwaan)                              0      360
# I-Melanggar UU (Pertimbangan Hukum)                   0      616
# I-Melanggar UU (Tuntutan)                             0       69
# I-Nama Hakim Anggota                                  0        1
# I-Nama Hakim Ketua                                    0        8
# I-Nama Jaksa                                          0        2
# I-Nama Panitera                                       0        2
# I-Nama Pengacara                                      0        7
# I-Nama Pengadilan                                     0        8
# I-Nama Saksi                                          0       88
# I-Nama Terdakwa                                       0       16
# I-Nomor Putusan                                       0       16
# I-Putusan Hukuman                                     0      289
# I-Tanggal Kejadian                                    0      265
# I-Tanggal Putusan                                     0       14
# I-Tingkat Kasus                                       0        9
# I-Tuntutan Hukuman                                 2219      210
# O                                                   190  1495559
#
# [41 rows x 41 columns]

# %%
df_confusion_mix.to_csv(f'real-analytics/{EXP_NAME}-confusion_mat.csv')

# %%
# import os
# os._exit(00)
